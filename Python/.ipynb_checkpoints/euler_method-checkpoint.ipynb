# %% [markdown]
# ## The Euler Method
# The [Euler method](https://en.wikipedia.org/wiki/Euler_method) for solving the first-order Ordinary Differential Equation (ODE) $y'(t)=f(t, y(t))$
#
# \begin{equation}
#     y_{n+1} = y_n + hf(t_n, y_n) + O(h^2),
# \end{equation}
#
# where $t_{n+1} = t_n + h$.
#
# ### Initial value problems
# The solution to an [Initial Value Problem (IVP)](https://en.wikipedia.org/wiki/Initial_value_problem) is the solution to an ODE over a specified domain of $t$ and an initial value of the solution at the lower bound of the domain
#
# $$ y' = f(t, y), \qquad t \in [t_{\min}, t_{\max}], \qquad y_0 = y(t_{\min}).$$
#
# To apply the Euler method to solve an IVP we loop through the domain and calculate the values of $y_{n+1}$ using the Euler method with the known values $t_{n}$ and $y_n$.
#
# The code below defines a function `euler` that solves an IVP where `tspan` is a two element array containing the lower and upper bounds of the $t$ domain, `y0` is the value of $y$ at the lower bound and `h` is the step length.

# %%
import numpy as np


def euler(tspan, y0, h):
    """
    This function calculates the solution to the following IVP using the Euler method
    
            y'(t) = f(t, y(t)), tspan = [tmin, tmax], y(tmin) = y0
    """  
    nsteps = int((tspan[1] - tspan[0]) / h)
    t = np.zeros(nsteps + 1)
    y = np.zeros(nsteps + 1)
    t[0] = tspan[0]
    y[0] = y0
    
    for n in range(nsteps):
        y[n+1] = y[n] + h * f(t[n], y[n])
        t[n+1] = t[n] + h
    
    return t, y

# %% [markdown]
# #### Example
# The code below uses the Euler method to calculate the solution to the IVP
#
# $$ y' = y \sin^2(t), \qquad t \in [0, 5], \qquad y_0 = 1,$$
#
# using a step length $h=0.5$.

# %%
# Define ODE function
def f(t, y):
    return y * np.sin(t)**2

# Definte variables
tspan = [0, 5]
y0 = 1
h = 0.5

# Invoke the Euler method to solve IVP
t, y = euler(tspan, y0, h)

# Output solution table
print(" t_n |   y_n\n{}".format("-" * 16))
for i in range(len(t)):
    print(" {:0.1f} | {:0.6f}".format(t[i], y[i]))
# Out:
#  t_n |   y_n
# ----------------
#  0.0 | 1.000000
#  0.5 | 1.000000
#  1.0 | 1.114924
#  1.5 | 1.509649
#  2.0 | 2.260696
#  2.5 | 3.195292
#  3.0 | 3.767519
#  3.5 | 3.805034
#  4.0 | 4.039137
#  4.5 | 5.195845
#  5.0 | 7.678329

# %% [markdown]
# The exact solution to this IVP is $y(t) = \exp(\frac{1}{2}(t - \sin(t)\cos(t))$. The code below plots the numerical solution obtained using the Euler method against the exact solution.

# %%
import matplotlib.pyplot as plt

texact = np.linspace(tspan[0], tspan[1], 100)
yexact = np.exp(0.5 * (texact - np.sin(texact) * np.cos(texact)))

fig, ax = plt.subplots()
ax.plot(texact, yexact, 'k-', label='exact')
ax.plot(t, y, 'bo-', label='euler')
ax.set_xlabel('t')
ax.set_ylabel('y(t)')
ax.legend()
plt.show()

# %% [markdown]
# Here we can see that the solution using the Euler method deviates from the exact solution. This is because the Euler method is a first-order method and the truncation errors at each step compound as we step through the solution. One way to improve our solution is to use a smaller step length.
#
# The code below repeats the solution for this IVP using a step length of $h=0.1$.

# %%
# Invoke the Euler method to solve IVP using a smaller step length
h = 0.1
t2, y2 = euler(tspan, y0, h)

# Plot numerical and exact solutions
fig, ax = plt.subplots()
ax.plot(texact, yexact, 'k-', label='exact')
ax.plot(t, y, 'bo-', label='euler (h=0.5)')
ax.plot(t2, y2, 'ro-', label='euler (h=0.1)')
ax.set_xlabel('t')
ax.set_ylabel('y(t)')
ax.legend()
plt.show()

# %% [markdown]
# <font size="2"><i>Dr Jon Shiach, Department of Computing and Mathematics, Manchester Metropolitan University</i></font>
